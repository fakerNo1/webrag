# %%
import requests

# %%
max_attempt = 3
attempt = 0
search_engine_id = "82c324b0622dd403d"
api_key = "AIzaSyAcE_uJ2MjMcMKS5_zBQE8tYwr_RB-ss0k"
query="数据库并发控制有哪些手段?"
google_url = f"https://www.googleapis.com/customsearch/v1?key={api_key}&q={query}&cx={search_engine_id}&num={10}"

# %%
proxies = {
    "http": "http://127.0.0.1:7895",   
    "https": "http://127.0.0.1:7895",  
    "socks5": "socks5://127.0.0.1:7895"  
}

# %%
response = requests.get(google_url, proxies=proxies)
response.raise_for_status()

# %%
data = response.json()
data
# Out:
# {'kind': 'customsearch#search',
#  'url': {'type': 'application/json',
#   'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'},
#  'queries': {'request': [{'title': 'Google Custom Search - 数据库并发控制有哪些手段?',
#     'totalResults': '184',
#     'searchTerms': '数据库并发控制有哪些手段?',
#     'count': 10,
#     'startIndex': 1,
#     'inputEncoding': 'utf8',
#     'outputEncoding': 'utf8',
#     'safe': 'off',
#     'cx': '82c324b0622dd403d'}],
#   'nextPage': [{'title': 'Google Custom Search - 数据库并发控制有哪些手段?',
#     'totalResults': '184',
#     'searchTerms': '数据库并发控制有哪些手段?',
#     'count': 10,
#     'startIndex': 11,
#     'inputEncoding': 'utf8',
#     'outputEncoding': 'utf8',
#     'safe': 'off',
#     'cx': '82c324b0622dd403d'}]},
#  'context': {'title': '菜鸟教程'},
#  'searchInformation': {'searchTime': 0.117453,
#   'formattedSearchTime': '0.12',
#   'totalResults': '184',
#   'formattedTotalResults': '184'},
#  'items': [{'kind': 'customsearch#result',
#    'title': '13.1. 介绍',
#    'htmlTitle': '13.1. 介绍',
#    'link': 'https://www.runoob.com/manual/PostgreSQL/mvcc-intro.html',
#    'displayLink': 'www.runoob.com',
#    'snippet': '在内部，数据一致性通过使用一种多版本模型（多版本并发控制， MVCC ）来维护。这就意味着每个SQL 语句看到的都只是一小段时间之前的数据快照（一个数据库版本），而不管底层数据\xa0...',
#    'htmlSnippet': '在内部，数据一致性通过使用一种多版本模型（多版本<b>并发控制</b>， MVCC ）来维护。这就意味着每个SQL 语句看到的都只是一小段时间之前的数据快照（一个<b>数据库</b>版本），而不管底层数据&nbsp;...',
#    'formattedUrl': 'https://www.runoob.com/manual/PostgreSQL/mvcc-intro.html',
#    'htmlFormattedUrl': 'https://www.runoob.com/manual/PostgreSQL/mvcc-intro.html'},
#   {'kind': 'customsearch#result',
#    'title': '13.5. 提醒',
#    'htmlTitle': '13.5. 提醒',
#    'link': 'https://www.runoob.com/manual/PostgreSQL/mvcc-caveats.html',
#    'displayLink': 'www.runoob.com',
#    'snippet': '第 13 章 并发控制, 起始页 · 下一页. 13.5. 提醒. 一些DDL 命令（当前只有TRUNCATE和 ... 这意味着新创建的数据库对象，例如表，对于并发的可重复读和可序列化事务是\xa0...',
#    'htmlSnippet': '第 13 章 <b>并发控制</b>, 起始页 &middot; 下一页. 13.5. 提醒. 一些DDL 命令（当前只有TRUNCATE和 ... 这意味着新创建的<b>数据库</b>对象，例如表，对于并发的可重复读和可序列化事务是&nbsp;...',
#    'formattedUrl': 'https://www.runoob.com/manual/PostgreSQL/mvcc-caveats.html',
#    'htmlFormattedUrl': 'https://www.runoob.com/manual/PostgreSQL/mvcc-caveats.html'},
#   {'kind': 'customsearch#result',
#    'title': 'PostgreSQL 教程| 菜鸟教程',
#    'htmlTitle': 'PostgreSQL 教程| 菜鸟教程',
#    'link': 'http://www.runoob.com/postgresql/postgresql-tutorial.html',
#    'displayLink': 'www.runoob.com',
#    'snippet': '每个数据库都有一个或多个不同的API 用于创建，访问，管理，搜索和复制所 ... 多版本并发控制：PostgreSQL使用多版本并发控制（MVCC，Multiversion concurrency\xa0...',
#    'htmlSnippet': '每个<b>数据库</b>都有一个或多个不同的API 用于创建，访问，管理，搜索和复制所 ... 多版本<b>并发控制</b>：PostgreSQL使用多版本<b>并发控制</b>（MVCC，Multiversion concurrency&nbsp;...',
#    'formattedUrl': 'http://www.runoob.com/postgresql/postgresql-tutorial.html',
#    'htmlFormattedUrl': 'http://www.runoob.com/postgresql/postgresql-tutorial.html',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTzUwMKFJYTqyurLnyx72JGaDdCE1ddYwfJWiHxpRdq1j0XnJbecWIjZZlD&s',
#       'width': '225',
#       'height': '225'}],
#     'metatags': [{'viewport': 'width=device-width, initial-scale=1.0',
#       'apple-mobile-web-app-title': '菜鸟教程'}],
#     'cse_image': [{'src': 'https://www.runoob.com/wp-content/uploads/2014/03/postgresql-11-1175122.png'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Redis 简介| 菜鸟教程',
#    'htmlTitle': 'Redis 简介| 菜鸟教程',
#    'link': 'http://www.runoob.com/redis/redis-intro.html',
#    'displayLink': 'www.runoob.com',
#    'snippet': '单线程模型也简化了并发控制的复杂性。 主从复制：Redis 支持主从复制，可以通过 ... Redis 与其他key-value 存储有什么不同？ Redis 与其他key-value 存储系统的\xa0...',
#    'htmlSnippet': '单线程模型也简化了<b>并发控制</b>的复杂性。 主从复制：Redis 支持主从复制，可以通过 ... Redis 与其他key-value 存储有什么不同？ Redis 与其他key-value 存储系统的&nbsp;...',
#    'formattedUrl': 'http://www.runoob.com/redis/redis-intro.html',
#    'htmlFormattedUrl': 'http://www.runoob.com/redis/redis-intro.html',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRtx_j7tjnIth7MiPMF0JI3lFHLmCmkaTlEu5cC47tAT82rAPwR6HDAbPsF&s',
#       'width': '128',
#       'height': '128'}],
#     'metatags': [{'viewport': 'width=device-width, initial-scale=1.0',
#       'apple-mobile-web-app-title': '菜鸟教程'}],
#     'cse_image': [{'src': 'https://www.runoob.com/wp-content/themes/runoob/assets/images/qrcode.png'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'SET TRANSACTION',
#    'htmlTitle': 'SET TRANSACTION',
#    'link': 'https://www.runoob.com/manual/PostgreSQL/sql-set-transaction.html',
#    'displayLink': 'www.runoob.com',
#    'snippet': '一个事务的隔离级别决定当其他事务并行运行时该事务能看见什么数据：. READ ... 更多有关事务隔离级别和并发控制的信息可见第 13 章。 事务的访问模式决定该事务\xa0...',
#    'htmlSnippet': '一个事务的隔离级别决定当其他事务并行运行时该事务能看见什么数据：. READ ... 更多有关事务隔离级别和<b>并发控制</b>的信息可见第 13 章。 事务的访问模式决定该事务&nbsp;...',
#    'formattedUrl': 'https://www.runoob.com/manual/PostgreSQL/sql-set-transaction.html',
#    'htmlFormattedUrl': 'https://www.runoob.com/manual/PostgreSQL/sql-set-transaction.html'},
#   {'kind': 'customsearch#result',
#    'title': '1. 何为PostgreSQL？',
#    'htmlTitle': '1. 何为PostgreSQL？',
#    'link': 'https://www.runoob.com/manual/PostgreSQL/intro-whatis.html',
#    'displayLink': 'www.runoob.com',
#    'snippet': '... 数据库系统中。 PostgreSQL是最初的伯克利代码的开源继承者。它支持大部分SQL 标准并且提供了许多现代特性：. 复杂查询; 外键; 触发器; 可更新视图; 事务完整性; 多版本并发\xa0...',
#    'htmlSnippet': '... <b>数据库</b>系统中。 PostgreSQL是最初的伯克利代码的开源继承者。它支持大部分SQL 标准并且提供了许多现代特性：. 复杂查询; 外键; 触发器; 可更新视图; 事务完整性; 多版本<b>并发</b>&nbsp;...',
#    'formattedUrl': 'https://www.runoob.com/manual/PostgreSQL/intro-whatis.html',
#    'htmlFormattedUrl': 'https://www.runoob.com/manual/PostgreSQL/intro-whatis.html'},
#   {'kind': 'customsearch#result',
#    'title': '菜鸟教程MongoDB 教程已更新至3.0 | 菜鸟教程',
#    'htmlTitle': '菜鸟教程MongoDB 教程已更新至3.0 | 菜鸟教程',
#    'link': 'http://www.runoob.com/w3cnote/runoob-mongodb-update-3.html',
#    'displayLink': 'www.runoob.com',
#    'snippet': '那么这款走到聚光灯下的存储引擎究竟具备哪些值得期待的特性呢？ 1、文档级别并发控制. WiredTiger通过MVCC实现文档级别的并发控制，即文档级别锁。这就允许多个客户端\xa0...',
#    'htmlSnippet': '那么这款走到聚光灯下的存储引擎究竟具备<b>哪些</b>值得期待的特性呢？ 1、文档级别<b>并发控制</b>. WiredTiger通过MVCC实现文档级别的<b>并发控制</b>，即文档级别锁。这就允许多个客户端&nbsp;...',
#    'formattedUrl': 'http://www.runoob.com/w3cnote/runoob-mongodb-update-3.html',
#    'htmlFormattedUrl': 'http://www.runoob.com/w3cnote/runoob-mongodb-update-3.html',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRuHeAoYdQpGykSy8yiBlrd0GbiJpfkYbGOKInFU4TjXL48ZpcZzfWYHzo&s',
#       'width': '356',
#       'height': '142'}],
#     'metatags': [{'viewport': 'width=device-width, initial-scale=1.0',
#       'apple-mobile-web-app-title': '菜鸟教程'}],
#     'cse_image': [{'src': 'https://www.runoob.com/wp-content/uploads/2015/09/mongodb2.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': '部分 II. SQL 语言',
#    'htmlTitle': '部分 II. SQL 语言',
#    'link': 'https://www.runoob.com/manual/PostgreSQL/sql.html',
#    'displayLink': 'www.runoob.com',
#    'snippet': '我们从描述 SQL 的一般语法开始，然后解释如何创建保存数据的结构、如何填充数据库以及如何查询它。 ... 并发控制 · 13.1. 介绍 · 13.2. 事务隔离 · 13.3. 显式锁定 · 13.4.',
#    'htmlSnippet': '我们从描述 SQL 的一般语法开始，然后解释如何创建保存数据的结构、如何填充<b>数据库</b>以及如何查询它。 ... <b>并发控制</b> &middot; 13.1. 介绍 &middot; 13.2. 事务隔离 &middot; 13.3. 显式锁定 &middot; 13.4.',
#    'formattedUrl': 'https://www.runoob.com/manual/PostgreSQL/sql.html',
#    'htmlFormattedUrl': 'https://www.runoob.com/manual/PostgreSQL/sql.html'},
#   {'kind': 'customsearch#result',
#    'title': 'MySQL 事务| 菜鸟教程',
#    'htmlTitle': 'MySQL 事务| 菜鸟教程',
#    'link': 'http://www.runoob.com/mysql/mysql-transaction.html',
#    'displayLink': 'www.runoob.com',
#    'snippet': '隔离性：数据库允许多个并发事务同时对其数据进行读写和修改的能力，隔离性 ... MYSQL 事务处理主要有两种方法：. 1、用BEGIN, ROLLBACK, COMMIT 来实现. BEGIN 或\xa0...',
#    'htmlSnippet': '隔离性：<b>数据库</b>允许多个<b>并发</b>事务同时对其数据进行读写和修改的能力，隔离性 ... MYSQL 事务处理主要有两种方法：. 1、用BEGIN, ROLLBACK, COMMIT 来实现. BEGIN 或&nbsp;...',
#    'formattedUrl': 'http://www.runoob.com/mysql/mysql-transaction.html',
#    'htmlFormattedUrl': 'http://www.runoob.com/mysql/mysql-transaction.html',
#    'pagemap': {'metatags': [{'viewport': 'width=device-width, initial-scale=1.0',
#       'apple-mobile-web-app-title': '菜鸟教程'}]}},
#   {'kind': 'customsearch#result',
#    'title': '3.4. 事务',
#    'htmlTitle': '3.4. 事务',
#    'link': 'https://www.runoob.com/manual/PostgreSQL/tutorial-transactions.html',
#    'displayLink': 'www.runoob.com',
#    'snippet': '步骤之间的中间状态对于其他并发事务是不可见的，并且如果有某些错误发生导致事务不能完成，则其中任何一个步骤都不会对数据库造成影响。 ... 并发运行时，每一个都不能\xa0...',
#    'htmlSnippet': '步骤之间的中间状态对于其他<b>并发</b>事务是不可见的，并且如果有某些错误发生导致事务不能完成，则其中任何一个步骤都不会对<b>数据库</b>造成影响。 ... <b>并发</b>运行时，每一个都不能&nbsp;...',
#    'formattedUrl': 'https://www.runoob.com/manual/PostgreSQL/tutorial-transactions.html',
#    'htmlFormattedUrl': 'https://www.runoob.com/manual/PostgreSQL/tutorial-transactions.html'}]}

# %%
import json
with open('test.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)
